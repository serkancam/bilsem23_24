# %%
# regresyon_basit.ipynb
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
veri=pd.read_csv("regresyon_veri1.csv")
veri.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ozellik1     40 non-null     int64
#  1   sinif-hedef  40 non-null     int64
# dtypes: int64(2)
# memory usage: 768.0 bytes

# %%
veri.head()
# Out:
#    ozellik1  sinif-hedef
# 0         1            7
# 1         3           11
# 2         4           18
# 3         5           19
# 4         6           24

# %%
sns.scatterplot(data=veri,x="ozellik1",y="sinif-hedef")
plt.show()

# %%
sns.lmplot(data=veri,x="ozellik1",y="sinif-hedef")
plt.show()

# %%
from sklearn.model_selection import train_test_split

X=veri.iloc[:,:-1].values
y=veri.iloc[:,-1].values

X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1,random_state=22)

# %%
from sklearn.linear_model import LinearRegression

regresyoncu = LinearRegression()

regresyoncu.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
x1_degeri=75
x2_degeri=37
tahmin=regresyoncu.predict(  [[x1_degeri],[x2_degeri]]   )
print("tahmin edilen:",tahmin)
# Out:
# tahmin edilen: [232.11972495 116.21941698]

# %%
egim=regresyoncu.coef_
kesisim=regresyoncu.intercept_
print(egim, kesisim)
# Out:
# [3.0500081] 3.36911711781012
