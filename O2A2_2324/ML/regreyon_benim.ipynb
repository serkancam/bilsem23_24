# %%
# regreyon_benim.ipynb
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
veri_ham=pd.read_csv("regresyon_veri2.csv")
veri_ham
# Out:
#     ozellik1  ozellik2  sinif-hedef
# 0         10         5           38
# 1         20        30           93
# 2          3         2           14
# 3          5         8           26
# 4          7        10           34
# 5         55         8          176
# 6         80        75          318
# 7         11         6           42
# 8         21        31           97
# 9          4         3           18
# 10         6         9           30
# 11         8        11           38
# 12        56         9          180
# 13        81        76          322
# 14        12         7           46
# 15        22        32          101
# 16         5         4           22
# 17         7        10           34
# 18         9        12           42
# 19        57        10          184
# 20        82        77          326
# 21        13         8           50
# 22        23        33          105
# 23         6         5           26
# 24         8        11           38
# 25        10        13           46
# 26        58        11          188
# 27         1        78           84
# 28        84        79          334
# 29        85        80          338
# 30        12        81          120
# 31        87        82          346
# 32        14        83          128
# 33        28        84          171
# 34        90        85          358
# 35        23        86          158
# 36         5         2           20
# 37        93        88          370
# 38        94        89          374
# 39        49         8          158
# 40        20         1           64
# 41        30         3           96
# 42         3        25           37
# 43        25        72          150
# 44        21         2           68
# 45        31         4          100
# 46         4        26           41
# 47        26        73          154
# 48        22         3           72
# 49        32         5          104

# %%
veri=veri_ham.copy()

# %%
X=veri.iloc[:,:-1].values
y=veri.iloc[:,-1].values

# %%
X[:,0]
# Out:
# array([10, 20,  3,  5,  7, 55, 80, 11, 21,  4,  6,  8, 56, 81, 12, 22,  5,
#         7,  9, 57, 82, 13, 23,  6,  8, 10, 58,  1, 84, 85, 12, 87, 14, 28,
#        90, 23,  5, 93, 94, 49, 20, 30,  3, 25, 21, 31,  4, 26, 22, 32])

# %%
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
ax.scatter3D(X[:,0], X[:,1], y, color = "green")
plt.title("simple 3D scatter plot")
 

plt.show()
